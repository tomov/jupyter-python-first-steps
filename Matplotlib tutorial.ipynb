# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %%
import numpy as np
x = np.linspace(0, np.pi * 2, 100)
y = np.sin(x)
z = np.cos(x)
plt.plot(x, y)
plt.plot(x, z)
plt.xlabel('x')
plt.legend(['sin(x)', 'cos(x)'])
plt.show()

# %%
plt.figure(figsize=(10,6), dpi=80)
plt.plot(x, y, color="blue", linewidth=2.5, linestyle="-")
plt.plot(x, z, color="red",  linewidth=2.5, linestyle="-")
plt.show()

# %%
from scipy.stats import norm
    
x = np.linspace(-5, 5, 100)
#print np.info(norm)
y = norm.pdf(x, -2, 1)
plt.plot(x, y, linewidth=2, color='red', linestyle='--')
plt.show()

# %%
from scipy.stats import multivariate_normal

x = np.array([0.1, 0.4, -0.1])
y = multivariate_normal.pdf([0, 0, 0], [0, 0, 0], [1, 1, 1])
print y
print np.eye(3) * 10
# Out:
# 0.0634936359342
# [[ 10.   0.   0.]
#  [  0.  10.   0.]
#  [  0.   0.  10.]]
